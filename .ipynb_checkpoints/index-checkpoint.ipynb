# %% [markdown]
# # FILMS ANALYSIS AT THE BOX OFFICE

# %% [markdown]
# ## OVERVIEW

# %% [markdown]
# This project uses exploratory data analysis to generate insights in movie patterns. The goal is to identify the type of films that are currently performing best at the box office and with that guide the company investment decisions as it starts its new movie studio. By cleaning, merging, grouping the data we understand what films are most appropriate and key factors behind their success.

# %% [markdown]
# ## BUSINESS PROBLEM

# %% [markdown]
# The company is determined to launch a new movie studio though they lack experience in film production. The aim of this analysis is to analyze
# what type of films are currently doing best at the box office, then turn the findings into practical recommendations that helps the company
# to strategically position itself and successfully enter the film industry.

# %% [markdown]
# ## DATA UNDERSTANDING

# %% [markdown]
# This project uses movie datasets from multiple locations with different file formats i.e CSV, SQLite.
# The primary dataset being used are
# 1. im database which is located in SQLite Database, with **movie_basics** and **movie_ratings** as the more applicable tables.
#
# movie_basics table contain the following columns;
# * movie_id "unique movie id number"
# * primary_title "movie title displayed for audience"
# * original_title "movie title as the createrors intended it"
# * start_year "year movie started"
# * runtime_minutes "movie duration in minutes"
# * genres "movie categories"
#
# and the movie_ratings table contain;
#
# * movie_id "unique movie id number"
# * averagerating "IMDb user ratings"
# * numvotes- "number of user votes per movie"
#
# **From the IMDB data we have "movie_id" column as the unique identification for movie_basics and movie_ratings tables**
#
# 2. bom.movie_gross.csv.gz  that has a csv formart, it includes the following columns;
# * title "representing the movie title"
# * studio "representing the production studio"
# * domestic_gross "total revenue generated by films locally"
# * foreign_gross "total revenue generated by films internationaly"
# * year "year of movie release"
#
# 3. movie_budgets.csv data which is in form of a csv fortmat contain the following columns;
# * worldwide_gross "representing the total international revenue generated by a movie"
# * domestic_gross "representing the total revenue generetated by a move locally"
# * production_budget "representing the amount spent during movie production"
# * movie "represnting the movie name"
# * release_date "date the film was released"
# * id " movie unique identifier"

# %% [markdown]
# # DATA PREPARATION

# %%
import pandas as pd
import sqlite3
import pandasql
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie_gross_df = pd.read_csv("./Data/bom.movie_gross.csv.gz")
movie_gross_df.head(7)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
# 5                   The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                   Iron Man 2   Par.     312400000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# 5     398000000  2010
# 6     311500000  2010

# %%
movie_budget_df = pd.read_csv("./Data/tn.movie_budgets.csv.gz")
movie_budget_df.head(7)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 6   7  Apr 27, 2018                       Avengers: Infinity War
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# 5      $306,000,000   $936,662,225  $2,053,311,220
# 6      $300,000,000   $678,815,482  $2,048,134,200

# %%
# creating a connection to sqlite database, then list all table names in the db
conn=sqlite3.connect("./Data/im.db")
df=pd.read_sql(
"""
SELECT name
FROM sqlite_master
WHERE type = "table"

""", conn)
df
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers
# 8  movie_details
# 9    movie_gross

# %%
movie_basics_df = pd.read_sql("""
SELECT *
FROM movie_basics
""", conn)
movie_basics_df.head(7)
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
# 6  tt0112502                          Bigfoot                     Bigfoot
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# 5        2018             75.0                Comedy
# ...

# %%
movie_ratings_df = pd.read_sql("""
SELECT *
FROM movie_ratings
""", conn)
movie_ratings_df.head(7)
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# 5   tt1069246            6.2       326
# 6   tt1094666            7.0      1613

# %%
movie_details_df = pd.read_sql("""
SELECT *
FROM movie_basics
JOIN movie_ratings
USING (movie_id);
""", conn)
movie_details_df.head(7)
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0112502                          Bigfoot                     Bigfoot
# 6  tt0137204                  Joe Finds Grace             Joe Finds Grace
#
#    start_year  runtime_minutes                      genres  averagerating  \
# 0        2013            175.0          Action,Crime,Drama            7.0
# 1        2019            114.0             Biography,Drama            7.2
# 2        2018            122.0                       Drama            6.9
# 3        2018              NaN                Comedy,Drama            6.1
# ...

# %%
movie_details_df.shape
# Out:
# (73856, 8)

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# a)Data cleaning in the (**movie_basics** and **movie_ratings**) movie_details table

# %%
movie_details_df.shape
# Out:
# (73856, 8)

# %% [markdown]
# 1. **genres column**

# %%
# nall values in the genres column
movie_details_df["genres"].isna().sum()
# Out:
# 804

# %%
movie_details_df["genres"].mode()
# Out:
# 0    Drama
# Name: genres, dtype: object

# %% [markdown]
# **we fill NaNs with mode because genres is a nominal categorical variable**

# %%
movie_details_df["genres"]=movie_details_df["genres"].fillna("Drama")

# %%
movie_details_df["genres"].isna().sum()
# Out:
# 0

# %% [markdown]
# 2. **Average ratings** column (movie ratings)

# %%
movie_details_df["averagerating"].isna().sum()
# Out:
# 0

# %%
movie_details_df["numvotes"].isna().sum()
# Out:
# 0

# %% [markdown]
# 3. **runtime_minutes** column (movie duration)**

# %%
movie_details_df["runtime_minutes"].isna().sum()
# Out:
# 7620

# %% [markdown]
# **In numerical variables we fill NaN with either mode, median or mean. In this case we will use median because it is unique and not affected by outliers**

# %%
movie_details_df["runtime_minutes"].median()
# Out:
# 91.0

# %%
movie_details_df["runtime_minutes"]=movie_details_df["runtime_minutes"].fillna(91.0)

# %%
movie_details_df["runtime_minutes"].isna().sum()
# Out:
# 0

# %% [markdown]
# 4. **primary_title** and **original_title** columns

# %%
movie_details_df["primary_title"].isna().sum()
# Out:
# 0

# %%
movie_details_df["original_title"].isna().sum()
# Out:
# 0

# %%
movie_details_df["start_year"].isna().sum()
# Out:
# 0

# %% [markdown]
# b) Data cleaning in **movie_budget** table

# %%
#cleaning by removing the $ and comma then converting values from strings to numbers/float
movie_budget_df["production_budget"]=movie_budget_df["production_budget"].astype(str).str.replace("$", "", regex=False).str.replace(",", "").astype(float)
movie_budget_df["domestic_gross"]=movie_budget_df["domestic_gross"].astype(str).str.replace("$", "", regex=False).str.replace(",", "").astype(float)
movie_budget_df["worldwide_gross"]=movie_budget_df["worldwide_gross"].astype(str).str.replace("$", "", regex=False).str.replace(",", "").astype(float)

# %%
movie_budget_df["movie"].isna().sum()
# Out:
# 0

# %%
movie_budget_df["production_budget"].isna().sum()
# Out:
# 0

# %%
movie_budget_df["domestic_gross"].isna().sum()
# Out:
# 0

# %%
movie_budget_df["worldwide_gross"].isna().sum()
# Out:
# 0

# %% [markdown]
# c) Data cleaning in **movie_gross** table

# %% [markdown]
# 1. **studio** column (movie studios)

# %%
movie_gross_df.shape
# Out:
# (3387, 5)

# %%
movie_gross_df["studio"].isna().sum()
# Out:
# 5

# %% [markdown]
# **We fill NaNs with the mode most common production studio**

# %%
movie_gross_df["studio"].mode()
# Out:
# 0    IFC
# Name: studio, dtype: object

# %%
movie_gross_df["studio"] = movie_gross_df["studio"].fillna("IFC")

# %%
movie_gross_df["studio"].isna().sum()
# Out:
# 0

# %% [markdown]
# 2. **domestic_gross** column (revenue generated domestically)

# %%
movie_gross_df["domestic_gross"].isna().sum()
# Out:
# 28

# %%
movie_gross_df["domestic_gross"].median()
# Out:
# 1400000.0

# %%
movie_gross_df["domestic_gross"] = movie_gross_df["domestic_gross"].fillna(1400000.0)

# %%
movie_gross_df["domestic_gross"].isna().sum()
# Out:
# 0

# %% [markdown]
# 3. **foreign_gross** column (revenue generated internationaly)

# %%
movie_gross_df["foreign_gross"].isna().mean()*100
# Out:
# 39.85828166519043

# %%
# converting values in primary_title and title columns to lowercase then removing whitespace
movie_basics_df.loc[:,"primary_title"]=movie_basics_df["primary_title"].str.strip().str.lower()
movie_gross_df.loc[:,"title"]=movie_gross_df["title"].str.strip().str.lower()

# %%
#converting movie_gross dataFrame into sqlite database table 
movie_gross_df.to_sql("movie_gross", conn, if_exists="replace",index=False)
# Out:
# 3387

# %%
pd.read_sql("PRAGMA table_info(movie_gross);", conn)
# Out:
#    cid            name     type  notnull dflt_value  pk
# 0    0           title     TEXT        0       None   0
# 1    1          studio     TEXT        0       None   0
# 2    2  domestic_gross     REAL        0       None   0
# 3    3   foreign_gross     TEXT        0       None   0
# 4    4            year  INTEGER        0       None   0

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# **a) How success vary across different studios**

# %%
movie_gross_df["domestic_gross"].describe()
# Out:
# count    3.387000e+03
# mean     2.851978e+07
# std      6.675093e+07
# min      1.000000e+02
# 25%      1.225000e+05
# 50%      1.400000e+06
# 75%      2.750000e+07
# max      9.367000e+08
# Name: domestic_gross, dtype: float64

# %%
studio_by_revenue=movie_gross_df.groupby("studio")["domestic_gross"].mean().sort_values(ascending=False)
studio_by_revenue.head(7)
# Out:
# studio
# BV         1.737644e+08
# P/DW       1.682900e+08
# WB (NL)    8.879333e+07
# Uni.       8.777138e+07
# WB         8.691461e+07
# Fox        8.051103e+07
# Sony       7.691894e+07
# Name: domestic_gross, dtype: float64

# %%
#Top studio by domestic gross
studio_by_revenue =movie_gross_df.groupby("studio")["domestic_gross"].mean().sort_values(ascending=False).head(10)

sns.barplot(x=studio_by_revenue.values, y=studio_by_revenue.index, color="blue")
plt.title("Top Studios by Domestic Gross")
plt.xlabel("domestic_gross")
plt.ylabel("studio_names")
plt.show()

# %% [markdown]
# * We want perform a statistical test to confirm if the domestic revenue differ across the studios.
# by comparing their means.
# * The appropriete statistical test for this particular analysis is ANOVA TEST, because we are comparing
# numeric vs categorical variables between more than 2 categorical groups(studios).

# %% [markdown]
# Stating the hypothesis
#
# **Null Hypothesis**: The means of domestic gross across the studios are the same
#
# **Alternative Hypothesis**: The means of domestic gross across the studios are not the same.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

formula = 'domestic_gross ~ C(studio)'
lm = ols(formula, movie_gross_df).fit()
sm.stats.anova_lm(lm)
# Out:
#                df        sum_sq       mean_sq         F         PR(>F)
# C(studio)   256.0  6.019250e+18  2.351270e+16  8.116139  5.873600e-203
# Residual   3130.0  9.067703e+18  2.897030e+15       NaN            NaN

# %% [markdown]
# **Conlusion**
#
# Since the p-value is < 0.05 we Reject the Null hypothesis.
#
# Hence we agree with the alternative hypothesis that domestic gross means are different across the studios,
# meaning there is a strong statistical evidence that studios that produce a movie have an impact on how much money it earns domestically.

# %% [markdown]
# **Recommendation**
#
# The company should study BV(Bueno Vista) a division of Disney studios strategy model in production being that it displayed the highest domestic mean gross

# %% [markdown]
# **b) Genre trends over-time**

# %%
# spliting strings with 2 or more genres in a string to one
movie_details_df["genres"] = movie_details_df["genres"].apply(lambda x: x.split(",") if isinstance(x,str) else x)
movie_details_df = movie_details_df.explode("genres")

genre_trends = pd.crosstab(movie_details_df["start_year"],movie_details_df["genres"])

genre_trends.plot(figsize=(11, 7))
plt.xlabel("Year")
plt.ylabel("Movies count")
plt.title("Trends in Movie Genres Across The Years")
plt.show()

# %% [markdown]
# **Observation**
#
# Over the years(2010-2018) Drama production dominated the film industry with over 3,000 films , followed by Comedy and Documentary
# with more than 1500 films each.

# %% [markdown]
# c)**Analyzing how the production budget relates with the worldwide gross revenue**

# %%
sns.scatterplot(data=movie_budget_df, x="production_budget", y="worldwide_gross")
plt.title("Production Budget vs Worldwide Gross")
plt.xlabel("Production Budget in ($)")
plt.ylabel("Worldwide Gross ($)")
plt.show()

# %%
from sklearn.model_selection import train_test_split
# target variables
x = movie_budget_df["production_budget"].values.reshape(-1,1)
y = movie_budget_df["worldwide_gross"].values
# spliting the data into test and train sets. 20% test, 80% train
budget_train, budget_test, gross_train, gross_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# building the model
from sklearn.linear_model import LinearRegression
# creating the model
model = LinearRegression()
# fiting the model using train data
model.fit(budget_train, gross_train)

#display the intercept (Bias)
print(model.intercept_)

#display the slope (coefficient)
print(model.coef_)
# Out:
# -7209247.681429565
# [3.12299278]

# %%
# comparing actual and predicted
gross_predict = model.predict(budget_test)
#creating a comparison DataFrame
comparison_frame = pd.DataFrame({"Actual" : gross_test.flatten(), "predicted" : gross_predict.flatten()})
#display stats
comparison_frame.describe()
# Out:
#              Actual     predicted
# count  1.157000e+03  1.157000e+03
# mean   9.022636e+07  8.998463e+07
# std    1.801500e+08  1.317490e+08
# min    0.000000e+00 -7.204875e+06
# 25%    4.956401e+06  8.405716e+06
# 50%    2.931789e+07  4.588163e+07
# 75%    9.602490e+07  1.177105e+08
# max    2.208208e+09  1.275092e+09

# %%
#plotting scatter and regression line
plt.scatter(budget_test, gross_test, color="black")
plt.plot(budget_test, gross_predict, color="red", linewidth=2)
plt.title("Production Budget vs Worldwide Gross Train-Test Linear Regression")
plt.xlabel("Production budget in ($)")
plt.ylabel("Worldwide Gross in ($)")
plt.tight_layout()
#plt.savefig("budgetVSworldwidegrossRegression.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# This plot shows simple linear regression between the films production budget in dollars(independent variable)  and worldwide gross in dollars
# (dependent variable), with each black dot representing a film and  the red line representing the regression line, showing the predicted worldwide gross
# in respect to production budget.

# %% [markdown]
# **Interpretation**
#
# The slope of the regression line is positive meaning there is a positve relationship between production budget and worldwide gross.
# As the production budget increases, the worldwide gross also increases, meaning bigger budget films result to higher income.
#
# There is a lot of movie spread at the low-budget (Below 100 million dollars) compared to the high-budget (Above 100 million dollars).
# At lower-budgets some films display high gross income while others don't. At higher-budgets, gross increased rapidly but still fluctuated in some cases.

# %% [markdown]
# Few spread of films around the regression line suggest that some other factors apart from the production budget i.e genre type, movie runtime
# duration also an effect on the worldwide gross.

# %% [markdown]
# ## Conlusion

# %% [markdown]
# 1. Analysis of the average domestic gross of films across different studios indicates a relationship between the studio producing the film and its
# local earnings. Showing that studio choice can significantly influence movie performance within the domestic market.

# %% [markdown]
# 2. Analysis of genre popularity from 2010 to 2018 shows that Drama was the most produced genre with over 3,000 films,
# followed by Comedy and Documentary with over 1500 films each.

# %% [markdown]
# 3. There is a postive relationship between movies production budget and worldwide gross income, meaning higher budget movies lead to higher
# foreign income. however, sometimes low budget movies display higher worldwide gross and high budget movies display lower worldwide gross this is as a
# result of effect of other factors i.e genre type, movie duration runtime on the worldwide gross.

# %% [markdown]
# ## Reccomendation

# %% [markdown]
# 1. The company should study Bueno Vista's (a division of Disney studios) production strategy, as it outperformed other studios in domestic box office
# market.

# %% [markdown]
# 2. The company should consider focusing on Drama, Comedy films as they've appeared to be popular genres being produced at the time, showing
# audience demand and potential success

# %% [markdown]
# 3. While higher production budgets leads to higher worldwide gross income, the company should not only depend on high budgets for success but also should
# focus on producing well-crafted Drama or comedy films with balanced budgets.
